# %% [markdown]
# <a href="https://colab.research.google.com/github/claudinez/Educ360_Seaborn_Graficos/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
dados = sns.load_dataset("tips")
display(dados.describe(include="all"))
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
dados = sns.load_dataset("tips")

# %%
#dados.info()
#display(dados.describe(include="all"))

# %%
sns.scatterplot(x="total_bill", y="tip", data=dados)
plt.title("Relação entre Total da Conta e Goreta")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-122765352.py in <cell line: 0>()
#       1 sns.scatterplot(x="total_bill", y="tip", data=dados)
# ----> 2 plt.title("Relação entre Total da Conta e Goreta")
#       3 plt.show
#
# NameError: name 'plt' is not defined

# %%
sns.regplot(x="total_bill", y="tip", data=dados)
plt.title("Relação entre Total da Conta e Goreta")
plt.show
#
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x="day", y="total_bill", data=dados, estimator="mean", palette="pastel")
plt.title("Gorjeta por dia da Semana")
plt.show()
# Out:
# /tmp/ipython-input-1414211143.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=dados, estimator="mean", palette="pastel")

# %%
sns.boxplot(x="day", y="total_bill", data=dados)
plt.title("Distribuição de valor das contas por dia")
plt.show()

# %%
# Histograma
sns.histplot(data=dados, x="total_bill", bins=5, kde=True, color="orange")
plt.title("Histograma da gorjeta")
plt.show()

# %%
# Violino

sns.violinplot(x="day", y="total_bill", data=dados)
plt.title("Distribuição de valor das contas por dia")
plt.show()

# %%
# linhas

#op = 'Female'
#dadosf = dados.sex == op
sns.lineplot(x="total_bill", y="tip", data=dados, marker="o", hue='sex')
plt.title(f"Relação entre Total da Conta e Goreta - Sexo {op}")
plt.show()
